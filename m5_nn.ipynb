# %%
calender = pd.read_csv('calendar.csv', index_col = 'date', parse_dates = True)
calender.index.freq = 'D'

price = pd.read_csv('sell_prices.csv')
sales = pd.read_csv('sales_train_validation.csv')
submission = pd.read_csv('sample_submission.csv')

# %%
print(f'price data memory usage = ~{price.memory_usage().sum()/1e6} MB')
print(f'price data memory usage = ~{sales.memory_usage().sum()/1e6} MB')
# Out:
# price data memory usage = ~218.916 MB
# price data memory usage = ~468.082608 MB

# %%
def reduce_mem_usage(df, verbose = True):
    numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
    start_mem = df.memory_usage().sum() / 1024**2    
    for col in df.columns:
        col_type = df[col].dtypes
        if col_type in numerics:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)    
    end_mem = df.memory_usage().sum() / 1024**2
    if verbose: print('Mem. usage decreased to {:5.2f} Mb ({:.1f}% reduction)'.format(end_mem, 100 * (start_mem - end_mem) / start_mem))
    return df

price = reduce_mem_usage(price)
sales = reduce_mem_usage(sales)
# Out:
# Mem. usage decreased to 130.48 Mb (37.5% reduction)
# Mem. usage decreased to 95.00 Mb (78.7% reduction)

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Bidirectional, LSTM, GRU, Dense, Conv2D, RNN
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint

# %%
sales.drop(['item_id', 'dept_id', 'cat_id', 'store_id', 'state_id'], axis = 1, inplace = True)
sales = sales.T
sales.columns = sales.iloc[0,]
sales.drop(index = 'id', inplace = True)
sales.head()
# Out:
# id  HOBBIES_1_001_CA_1_validation  ... FOODS_3_827_WI_3_validation
# d_1                             0  ...                           0
# d_2                             0  ...                           0
# d_3                             0  ...                           0
# d_4                             0  ...                           0
# d_5                             0  ...                           0
#
# [5 rows x 30490 columns]

# %%
n_obs = 28
train = sales[-n_obs*4:-n_obs]
test = sales[-n_obs:]

# %%
scaler = MinMaxScaler()
scaled_train = scaler.fit_transform(train)
scaled_test = scaler.transform(test)

# %%
scaled_train.shape
# Out:
# (84, 30490)

# %%
scaled_test.shape
# Out:
# (28, 30490)

# %%
n_input = 7
n_features = scaled_train.shape[1]
train_generator = TimeseriesGenerator(scaled_train, scaled_train, length = n_input, batch_size = 1)
test_generator = TimeseriesGenerator(scaled_test, scaled_test, length = n_input, batch_size = 1)

# %%
model = Sequential()
model.add(Bidirectional(LSTM(128, 'relu', kernel_initializer = 'glorot_normal',
                             return_sequences = True), input_shape = (n_input, n_features)))
model.add(Bidirectional(LSTM(64, 'relu', kernel_initializer = 'glorot_normal')))
model.add(Dense(scaled_train.shape[1]))
early_stop = EarlyStopping(monitor = 'val_loss', patience = 20)
reduce_lr = ReduceLROnPlateau(monitor = 'val_loss', factor = 0.1, patience = 20, min_lr = 0.001)
checkpoint = ModelCheckpoint('model.h5', monitor = 'val_loss', save_best_only = True, mode = 'min')
model.compile('adam', loss = 'mse', metrics = [tf.keras.metrics.RootMeanSquaredError()])
model.summary()
history = model.fit(train_generator, epochs = 500, verbose = 1, 
                    validation_data = test_generator, 
                    callbacks = [checkpoint, reduce_lr, early_stop])
# Out:
# Traceback (most recent call last):
#
#   File "<ipython-input-70-5f37e6c7ea3a>", line 3, in <module>
#     return_sequences = True), input_shape = (n_input, n_features)))
#
#   File "C:\Users\admin\Anaconda3\lib\site-packages\tensorflow_core\python\training\tracking\base.py", line 457, in _method_wrapper
#     result = method(self, *args, **kwargs)
#
#   File "C:\Users\admin\Anaconda3\lib\site-packages\tensorflow_core\python\keras\engine\sequential.py", line 185, in add
#     layer(x)
#
#   File "C:\Users\admin\Anaconda3\lib\site-packages\tensorflow_core\python\keras\layers\wrappers.py", line 543, in __call__
#     return super(Bidirectional, self).__call__(inputs, **kwargs)
#
#   File "C:\Users\admin\Anaconda3\lib\site-packages\tensorflow_core\python\keras\engine\base_layer.py", line 748, in __call__
#     self._maybe_build(inputs)
#
#   File "C:\Users\admin\Anaconda3\lib\site-packages\tensorflow_core\python\keras\engine\base_layer.py", line 2116, in _maybe_build
#     self.build(input_shapes)
#
#   File "C:\Users\admin\Anaconda3\lib\site-packages\tensorflow_core\python\keras\layers\wrappers.py", line 697, in build
#     self.forward_layer.build(input_shape)
#
#   File "C:\Users\admin\Anaconda3\lib\site-packages\tensorflow_core\python\keras\layers\recurrent.py", line 564, in build
#     self.cell.build(step_input_shape)
#
#   File "C:\Users\admin\Anaconda3\lib\site-packages\tensorflow_core\python\keras\utils\tf_utils.py", line 306, in wrapper
#     output_shape = fn(instance, input_shape)
#
#   File "C:\Users\admin\Anaconda3\lib\site-packages\tensorflow_core\python\keras\layers\recurrent.py", line 2301, in build
#     caching_device=default_caching_device)
#
#   File "C:\Users\admin\Anaconda3\lib\site-packages\tensorflow_core\python\keras\engine\base_layer.py", line 446, in add_weight
#     caching_device=caching_device)
#
#   File "C:\Users\admin\Anaconda3\lib\site-packages\tensorflow_core\python\training\tracking\base.py", line 744, in _add_variable_with_custom_getter
#     **kwargs_for_getter)
#
#   File "C:\Users\admin\Anaconda3\lib\site-packages\tensorflow_core\python\keras\engine\base_layer_utils.py", line 142, in make_variable
#     shape=variable_shape if variable_shape else None)
#
#   File "C:\Users\admin\Anaconda3\lib\site-packages\tensorflow_core\python\ops\variables.py", line 258, in __call__
#     return cls._variable_v1_call(*args, **kwargs)
#
#   File "C:\Users\admin\Anaconda3\lib\site-packages\tensorflow_core\python\ops\variables.py", line 219, in _variable_v1_call
#     shape=shape)
#
#   File "C:\Users\admin\Anaconda3\lib\site-packages\tensorflow_core\python\ops\variables.py", line 197, in <lambda>
#     previous_getter = lambda **kwargs: default_variable_creator(None, **kwargs)
#
#   File "C:\Users\admin\Anaconda3\lib\site-packages\tensorflow_core\python\ops\variable_scope.py", line 2596, in default_variable_creator
#     shape=shape)
#
#   File "C:\Users\admin\Anaconda3\lib\site-packages\tensorflow_core\python\ops\variables.py", line 262, in __call__
#     return super(VariableMetaclass, cls).__call__(*args, **kwargs)
#
#   File "C:\Users\admin\Anaconda3\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py", line 1411, in __init__
#     distribute_strategy=distribute_strategy)
#
#   File "C:\Users\admin\Anaconda3\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py", line 1542, in _init_from_args
#     initial_value() if init_from_fn else initial_value,
#
#   File "C:\Users\admin\Anaconda3\lib\site-packages\tensorflow_core\python\keras\engine\base_layer_utils.py", line 122, in <lambda>
#     init_val = lambda: initializer(shape, dtype=dtype)
#
#   File "C:\Users\admin\Anaconda3\lib\site-packages\tensorflow_core\python\ops\init_ops_v2.py", line 419, in __call__
#     return self._random_generator.truncated_normal(shape, 0.0, stddev, dtype)
#
#   File "C:\Users\admin\Anaconda3\lib\site-packages\tensorflow_core\python\ops\init_ops_v2.py", line 797, in truncated_normal
#     shape=shape, mean=mean, stddev=stddev, dtype=dtype, seed=self.seed)
#
#   File "C:\Users\admin\Anaconda3\lib\site-packages\tensorflow_core\python\ops\random_ops.py", line 175, in truncated_normal
#     shape_tensor, dtype, seed=seed1, seed2=seed2)
#
#   File "C:\Users\admin\Anaconda3\lib\site-packages\tensorflow_core\python\ops\gen_random_ops.py", line 899, in truncated_normal
#     _ops.raise_from_not_ok_status(e, name)
#
#   File "C:\Users\admin\Anaconda3\lib\site-packages\tensorflow_core\python\framework\ops.py", line 6606, in raise_from_not_ok_status
#     six.raise_from(core._status_to_exception(e.code, message), None)
#
#   File "<string>", line 3, in raise_from
#
# ResourceExhaustedError: OOM when allocating tensor with shape[30490,512] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc [Op:TruncatedNormal]

# %%
plt.plot(history.history['loss'], label = 'loss')
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.legend()

# %%
scaled_train.shape

# %%
test_predictions = []
first_eval_batch = scaled_train[-n_input:]
current_batch = first_eval_batch.reshape((1, n_input, n_features))

for i in range(len(test)):
    current_pred = model.predict(current_batch)[0]
    test_predictions.append(current_pred)
    current_batch = np.append(current_batch[:,1:,:], [[current_pred]], axis = 1)
    
predictions = scaler.inverse_transform(test_predictions)

# %%
predictions.shape

# %%
plt.plot(test.iloc[:,3], label = 'test data')
plt.plot(predictions[:,3], label = 'prediction')
plt.legend()

# %%
predictions[:,3]
# Out:
# array([1.48061895, 1.28858781, 1.26344228, 1.09920239, 1.51856065,
#        2.05800223, 1.78404617, 1.23099172, 1.08963072, 1.10345483,
#        0.92788398, 1.14709926, 1.75660539, 1.61020374, 1.1475426 ,
#        1.02979255, 1.06250978, 0.92944854, 0.9387992 , 1.56627214,
#        1.52001464, 1.13284647, 1.02094209, 1.06261194, 0.97362465,
#        0.82801443, 1.4314189 , 1.46612239])
